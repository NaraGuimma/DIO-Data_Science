# %%
# Importing pandas library
import pandas as pd

# %%
df = pd.read_csv("/content/Gapminder.csv", error_bad_lines=False, sep=";")

# %%
# Printing the first 5 lines of the dataframe
df.head(5)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# Printing the last 5 lines 
df.tail(5)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 3307  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 3308  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 3309  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 3310  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 3311  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
# Changing column names
df = df.rename(columns={"country": "País", "continent": "Continente", "year": "Ano", "lifeExp": "Expectativa de Vida", "pop": "População Total", "gdpPercap": "PIB" })

# %%
df
# Out:
#              País Continente  ...  População Total         PIB
# 0     Afghanistan       Asia  ...          8425333  779.445314
# 1     Afghanistan       Asia  ...          9240934  820.853030
# 2     Afghanistan       Asia  ...         10267083  853.100710
# 3     Afghanistan       Asia  ...         11537966  836.197138
# 4     Afghanistan       Asia  ...         13079460  739.981106
# ...           ...        ...  ...              ...         ...
# 3307     Zimbabwe     Africa  ...          9216418  706.157306
# 3308     Zimbabwe     Africa  ...         10704340  693.420786
# 3309     Zimbabwe     Africa  ...         11404948  792.449960
# 3310     Zimbabwe     Africa  ...         11926563  672.038623
# 3311     Zimbabwe     Africa  ...         12311143  469.709298
#
# [3312 rows x 6 columns]

# %%
# Showing the number of lines and columns in the dataframe 
df.shape
# Out:
# (3312, 6)

# %%
# Getting column names
df.columns
# Out:
# Index(['País', 'Continente', 'Ano', 'Expectativa de Vida', 'População Total',
#        'PIB'],
#       dtype='object')

# %%
# Knowing the type of content or data/ in each column
# object == string
df.dtypes
# Out:
# País                    object
# Continente              object
# Ano                      int64
# Expectativa de Vida    float64
# População Total          int64
# PIB                    float64
# dtype: object

# %%
# Getting initial statistical information from our dataframe
df.describe()
# Out:
#                Ano  Expectativa de Vida  População Total            PIB
# count  3312.000000          3312.000000     3.312000e+03    3312.000000
# mean   1980.301630            65.246871     3.161489e+07   11317.115805
# std      16.927294            11.768412     1.041193e+08   11369.142739
# min    1950.000000            23.599000     5.941200e+04     241.165877
# 25%    1967.000000            58.337500     2.678572e+06    2514.625266
# 50%    1982.000000            69.610000     7.557218e+06    7838.505123
# 75%    1996.000000            73.657750     1.958522e+07   17357.879170
# max    2007.000000            82.670000     1.318683e+09  113523.132900

# %%
# Showing the unique values of the column continent
df["Continente"].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
# Returning only the values when continent is Oceania
oceania = df.loc[df["Continente"] == "Oceania"]

# %%
oceania
# Out:
#                  País Continente  ...  População Total          PIB
# 975              Fiji    Oceania  ...           421869  2039.393277
# 976              Fiji    Oceania  ...           485000  2170.073285
# 977              Fiji    Oceania  ...           544000  2797.759484
# 978              Fiji    Oceania  ...           599339  3182.569600
# 979              Fiji    Oceania  ...           658906  3209.257468
# ...               ...        ...  ...              ...          ...
# 2696  Solomon Islands    Oceania  ...           300694  1783.648762
# 2697  Solomon Islands    Oceania  ...           358713  2109.894257
# 2698  Solomon Islands    Oceania  ...           424265  2252.491044
# 2699  Solomon Islands    Oceania  ...           494786  1530.496068
# 2700  Solomon Islands    Oceania  ...           566842  1829.317402
#
# [74 rows x 6 columns]

# %%
oceania["País"].unique()
# Out:
# array(['Fiji', 'New Zealand', 'Solomon Islands'], dtype=object)

# %%
# Grouping by continent, counting the number of countries registered for each one
df.groupby("Continente")["País"].nunique()
# Out:
# Continente
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: País, dtype: int64

# %%
# Average of life expectation for each country
df.groupby("País")["Expectativa de Vida"].mean()
# Out:
# País
# Afghanistan           37.478833
# Albania               68.432917
# Algeria               59.030167
# Angola                37.883500
# Argentina             69.060417
#                         ...
# Vietnam               57.479500
# West Bank and Gaza    60.328667
# Yemen, Rep.           46.780417
# Zambia                45.996333
# Zimbabwe              52.663167
# Name: Expectativa de Vida, Length: 187, dtype: float64

# %%
# Doing the same, but now separating by year
df.groupby("Ano")["Expectativa de Vida"].mean()
# Out:
# Ano
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283437
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...

# %%
df["PIB"].mean()
# Out:
# 11317.115804696637

# %%
df["PIB"].sum()
# Out:
# 37482287.5451553
